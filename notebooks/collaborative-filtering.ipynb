# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegressionCV
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def cf_rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten()
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
df_review_train = pd.read_csv("Montreal_review_train.csv")
df_review_test = pd.read_csv("Montreal_review_test.csv")
df_user_train = pd.read_csv("Montreal_user_train.csv")
df_user_test = pd.read_csv("Montreal_user_test.csv")
df_business_train = pd.read_csv("Montreal_business_train.csv")
df_business_test = pd.read_csv("Montreal_business_test.csv")

# %%
df_user_train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  average_stars  compliment_cool  compliment_cute  \
# 0           0            10           4.10             1302               41
# 1           1            13           3.79             1139               87
# 2           2            37           3.74              129                2
# 3           3           110           4.07               60                1
# 4           4           117           3.64               23                2
#
#    compliment_funny  compliment_hot  compliment_list  compliment_more  \
# 0              1302             806               20               46
# 1              1139             782               54              103
# 2               129              77                6               12
# 3                60              51                1               16
# 4                23              31                0                3
#
#    compliment_note     ...       \
# 0              725     ...
# 1              391     ...
# 2               56     ...
# 3               19     ...
# 4               13     ...
#
#                                               elite  fans  \
# 0        [2016, 2014, 2015, 2017, 2012, 2011, 2013]   435
# 1  [2012, 2008, 2009, 2010, 2007, 2006, 2013, 2011]   198
# 2        [2017, 2016, 2012, 2014, 2015, 2011, 2013]    68
# 3        [2014, 2012, 2015, 2011, 2013, 2016, 2017]    33
# 4                                      [2012, 2013]    15
#
#                                              friends  funny      name  \
# 0  ['xRYvFaMGWsvKcLCFtRIzWQ', 'zvQ7B3KZuFOX7pYLsO...   4880      Risa
# 1  ['KOwp5RDbm7cDyrdXN8FVQQ', '7MlH7OevWSkenMyKFI...  10715     Holly
# 2  ['Cq8uhBLRO1T9l-9R9OmddQ', 'x3_b9Rv-GZpjtCDLqg...    105      Jeff
# 3  ['8s7UH21vFgkRJAJg2L8VzA', 'HWGrt1MEXlzZ71NGx0...      9   Cecille
# 4  ['G-Hav6XBWPEyzI-0nNpdxw', 'EgqsK7MUgqpbaTVZAv...     36  Carolina
#
#   review_count  useful                 user_id  yelping_since elite_status
# 0         1122   26395  Wc5L6iuvSNF5WGBlqIO8nw     2011-07-30          Yes
# 1          698   24047  Dd-TkEszFMkSF-vRih51fQ     2006-07-03          Yes
# 2          754     151  YTdNcIWAt2nEzZ7NY-fniw     2011-05-16          Yes
# 3          356      36  bTRFge5pRWMh7IoCLn7lBw     2007-08-03          Yes
# 4          115      89  -w7ww3yW5BHE3TFyj3IHuQ     2010-06-29          Yes
#
# [5 rows x 25 columns]

# %%
# checking dimensions and unique users before fitting the model
# count number of unique reviews
print(df_review_train.shape)
print(len(df_review_train['user_id'].unique()))
print(len(df_review_train['business_id'].unique()))

# count number of uniqe users
print(df_user_train.shape)
print(len(df_user_train['user_id'].unique()))

# count number of uniqe business
print(df_business_train.shape)
print(len(df_business_train['business_id'].unique()))
# Out:
# (30999, 11)
# 3201
# 2429
# (3201, 25)
# 3201
# (2429, 18)
# 2429

# %%
# creating a user/restaurant pivot table
pivot_review_train = df_review_train.pivot(index = 'user_id', columns ='business_id', values = 'stars').fillna(0)
pivot_review_test = df_review_test.pivot(index = 'user_id', columns ='business_id', values = 'stars').fillna(0)

# %%
from scipy.sparse.linalg import svds

# %%
# Singular Value Decomposition (SVD) for users
def user_svd_predict(df, df_):
    R = df.as_matrix()
    user_ratings_mean = np.mean(R, axis = 1)
    R_demeaned = R - user_ratings_mean.reshape(-1, 1)
    
    U = []
    sigma = []
    Vt = []
    U, sigma, Vt = svds(R_demeaned, k=20)
    sigma = np.diag(sigma)
    all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    average_rating = list(df_['average_stars'])
    average_rating = np.array(average_rating).reshape(-1, 1)
    average_rating = np.repeat(average_rating, all_user_predicted_ratings.shape[1], axis=1)
    all_user_predicted_ratings_total = all_user_predicted_ratings + average_rating
    return (all_user_predicted_ratings_total, all_user_predicted_ratings)

# %%
# Singular Value Decomposition (SVD) for business
def business_svd_predict(df, df_):
    R = df.as_matrix()
    user_ratings_mean = np.mean(R, axis = 1)
    R_demeaned = R - user_ratings_mean.reshape(-1, 1)
    
    U = []
    sigma = []
    Vt = []
    U, sigma, Vt = svds(R_demeaned, k=20)
    sigma = np.diag(sigma)
    all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    average_rating = list(df_['stars'])
    average_rating = np.array(average_rating).reshape(-1, 1)
    average_rating = np.repeat(average_rating, all_user_predicted_ratings.shape[1], axis=1)
    all_user_predicted_ratings_total = all_user_predicted_ratings + average_rating
    return (all_user_predicted_ratings_total, all_user_predicted_ratings)

# %%
all_user_predicted_ratings_total = user_svd_predict(pivot_review_train, df_user_train)[0]
all_user_predicted_ratings_total_test = user_svd_predict(pivot_review_test, df_user_test)[0]
all_business_predicted_ratings_total = business_svd_predict(pivot_review_train.T, df_business_train)[0]
all_business_predicted_ratings_total_test = business_svd_predict(pivot_review_test.T, df_business_test)[0]

# %%
user_id_train = df_user_train['user_id']
user_id_test = df_user_test['user_id']

business_id_train = df_business_train['business_id']
business_id_test = df_business_test['business_id']

# %%
preds_df_train = pd.DataFrame(all_user_predicted_ratings_total, columns=pivot_review_train.columns, index=user_id_train)
preds_df_train.head()
# Out:
# business_id             -0uEqc2vw1xXtuI_r1xTNg  -1xuC540Nycht_iWFeJ-dw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.094261                4.240964
# Dd-TkEszFMkSF-vRih51fQ                3.795136                3.815809
# YTdNcIWAt2nEzZ7NY-fniw                3.749236                3.817079
# bTRFge5pRWMh7IoCLn7lBw                4.092210                4.509308
# -w7ww3yW5BHE3TFyj3IHuQ                3.639581                3.764347
#
# business_id             -7bRnaHp7OHz8KW-THqP4w  -92cC6-X87HQ1DE1UHOx3w  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.093483                4.127661
# Dd-TkEszFMkSF-vRih51fQ                3.795515                3.798954
# YTdNcIWAt2nEzZ7NY-fniw                3.748527                3.757432
# bTRFge5pRWMh7IoCLn7lBw                4.090106                4.152235
# -w7ww3yW5BHE3TFyj3IHuQ                3.639625                3.662383
#
# business_id             -AgfhwHOYrsPKt-_xV_Ipg  -BPHhtX6zzI59IX7ZY-AQA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.099962                4.098311
# Dd-TkEszFMkSF-vRih51fQ                3.795709                3.795789
# YTdNcIWAt2nEzZ7NY-fniw                3.750475                3.751114
# bTRFge5pRWMh7IoCLn7lBw                4.101792                4.104338
# -w7ww3yW5BHE3TFyj3IHuQ                3.638872                3.644714
#
# business_id             -FDkvLmwaBrtVgYFqEWeWA  -FPc3kwUU9GTDd4LzurvTQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.099023                4.093190
# Dd-TkEszFMkSF-vRih51fQ                3.796298                3.795232
# YTdNcIWAt2nEzZ7NY-fniw                3.749137                3.748381
# bTRFge5pRWMh7IoCLn7lBw                4.097496                4.088443
# -w7ww3yW5BHE3TFyj3IHuQ                3.642259                3.638670
#
# business_id             -GHqz1jGYzAtn27CeHeWeA  -HsqnPAz374YSoyFDyjl3A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.094802                4.143096
# Dd-TkEszFMkSF-vRih51fQ                3.795024                3.803154
# YTdNcIWAt2nEzZ7NY-fniw                3.748697                3.757516
# bTRFge5pRWMh7IoCLn7lBw                4.089012                4.167343
# -w7ww3yW5BHE3TFyj3IHuQ                3.636508                3.672317
#
# business_id                      ...            zqV3T9HltH1pmlRFJJSFcA  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          4.109433
# Dd-TkEszFMkSF-vRih51fQ           ...                          3.795918
# YTdNcIWAt2nEzZ7NY-fniw           ...                          3.756116
# bTRFge5pRWMh7IoCLn7lBw           ...                          4.132688
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          3.651202
#
# business_id             zr2wA55AskfBJxrvUeDZRA  zrnP9HqoF-RI9jqoW8pytA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.132640                4.094520
# Dd-TkEszFMkSF-vRih51fQ                3.795367                3.795871
# YTdNcIWAt2nEzZ7NY-fniw                3.770139                3.747204
# bTRFge5pRWMh7IoCLn7lBw                4.203549                4.084595
# -w7ww3yW5BHE3TFyj3IHuQ                3.673610                3.638274
#
# business_id             zsMMlOYtXm8SNy0bl1leBA  zsbsLCO-bw3gdNE9XNgBYw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.115686                4.102577
# Dd-TkEszFMkSF-vRih51fQ                3.796287                3.797605
# YTdNcIWAt2nEzZ7NY-fniw                3.758025                3.747736
# bTRFge5pRWMh7IoCLn7lBw                4.142995                4.095679
# -w7ww3yW5BHE3TFyj3IHuQ                3.655888                3.643778
#
# business_id             zv92BYJH09YjFQOtSyYp-A  zwBEMcCVqh8wOXn_sOIfxg  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.093049                4.098747
# Dd-TkEszFMkSF-vRih51fQ                3.795475                3.797292
# YTdNcIWAt2nEzZ7NY-fniw                3.747685                3.747688
# bTRFge5pRWMh7IoCLn7lBw                4.085720                4.093583
# -w7ww3yW5BHE3TFyj3IHuQ                3.638415                3.641998
#
# business_id             zwgVuZcMgijt9k3Jq-2zQQ  zwkif4XLEDqdEwEgTWLIVQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.095100                4.119639
# Dd-TkEszFMkSF-vRih51fQ                3.795636                3.797662
# YTdNcIWAt2nEzZ7NY-fniw                3.748463                3.756472
# bTRFge5pRWMh7IoCLn7lBw                4.090215                4.140908
# -w7ww3yW5BHE3TFyj3IHuQ                3.639788                3.654747
#
# business_id             zzjKekzQ6i4iR-qpo405Pw
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.098103
# Dd-TkEszFMkSF-vRih51fQ                3.795856
# YTdNcIWAt2nEzZ7NY-fniw                3.751034
# bTRFge5pRWMh7IoCLn7lBw                4.104515
# -w7ww3yW5BHE3TFyj3IHuQ                3.642414
#
# [5 rows x 2429 columns]

# %%
preds_df_test = pd.DataFrame(all_user_predicted_ratings_total_test, columns=pivot_review_test.columns, index=user_id_test)
preds_df_test.head()
# Out:
# business_id             -0uEqc2vw1xXtuI_r1xTNg  -1xuC540Nycht_iWFeJ-dw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102510                4.110007
# Dd-TkEszFMkSF-vRih51fQ                3.790563                3.789336
# YTdNcIWAt2nEzZ7NY-fniw                3.742230                3.737859
# bTRFge5pRWMh7IoCLn7lBw                4.078794                4.122720
# -w7ww3yW5BHE3TFyj3IHuQ                3.642450                3.654639
#
# business_id             -7bRnaHp7OHz8KW-THqP4w  -92cC6-X87HQ1DE1UHOx3w  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102534                4.102885
# Dd-TkEszFMkSF-vRih51fQ                3.790566                3.790516
# YTdNcIWAt2nEzZ7NY-fniw                3.742241                3.742058
# bTRFge5pRWMh7IoCLn7lBw                4.078413                4.079142
# -w7ww3yW5BHE3TFyj3IHuQ                3.642340                3.643128
#
# business_id             -AgfhwHOYrsPKt-_xV_Ipg  -FDkvLmwaBrtVgYFqEWeWA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102467                4.102479
# Dd-TkEszFMkSF-vRih51fQ                3.790554                3.790560
# YTdNcIWAt2nEzZ7NY-fniw                3.742187                3.742228
# bTRFge5pRWMh7IoCLn7lBw                4.080528                4.078799
# -w7ww3yW5BHE3TFyj3IHuQ                3.642614                3.642305
#
# business_id             -FPc3kwUU9GTDd4LzurvTQ  -HsqnPAz374YSoyFDyjl3A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102763                4.102247
# Dd-TkEszFMkSF-vRih51fQ                3.790560                3.790465
# YTdNcIWAt2nEzZ7NY-fniw                3.742240                3.741911
# bTRFge5pRWMh7IoCLn7lBw                4.079100                4.084911
# -w7ww3yW5BHE3TFyj3IHuQ                3.642277                3.641956
#
# business_id             -MwaICRwxaUi0JBfad2Y3Q  -Mz3M0g6iFZczs6a7ddf5g  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102289                4.104428
# Dd-TkEszFMkSF-vRih51fQ                3.790527                3.790369
# YTdNcIWAt2nEzZ7NY-fniw                3.742093                3.741819
# bTRFge5pRWMh7IoCLn7lBw                4.080099                4.087041
# -w7ww3yW5BHE3TFyj3IHuQ                3.642936                3.641301
#
# business_id                      ...            zktCQRlDtF6XmOpqKBz1mA  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          4.103460
# Dd-TkEszFMkSF-vRih51fQ           ...                          3.790459
# YTdNcIWAt2nEzZ7NY-fniw           ...                          3.741991
# bTRFge5pRWMh7IoCLn7lBw           ...                          4.082517
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          3.642076
#
# business_id             zmQyE-gIUpwBCMmTFFRbJw  zpw5S3QwUse1MH-Eerbnaw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102425                4.102717
# Dd-TkEszFMkSF-vRih51fQ                3.790552                3.790517
# YTdNcIWAt2nEzZ7NY-fniw                3.742182                3.742086
# bTRFge5pRWMh7IoCLn7lBw                4.079704                4.083314
# -w7ww3yW5BHE3TFyj3IHuQ                3.642766                3.642744
#
# business_id             zqV3T9HltH1pmlRFJJSFcA  zr2wA55AskfBJxrvUeDZRA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.099520                4.103339
# Dd-TkEszFMkSF-vRih51fQ                3.790075                3.790373
# YTdNcIWAt2nEzZ7NY-fniw                3.739798                3.741622
# bTRFge5pRWMh7IoCLn7lBw                4.125264                4.082772
# -w7ww3yW5BHE3TFyj3IHuQ                3.665249                3.643117
#
# business_id             zrnP9HqoF-RI9jqoW8pytA  zsMMlOYtXm8SNy0bl1leBA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102584                4.102180
# Dd-TkEszFMkSF-vRih51fQ                3.790565                3.790518
# YTdNcIWAt2nEzZ7NY-fniw                3.742217                3.742059
# bTRFge5pRWMh7IoCLn7lBw                4.077376                4.082331
# -w7ww3yW5BHE3TFyj3IHuQ                3.642087                3.643506
#
# business_id             zwBEMcCVqh8wOXn_sOIfxg  zwgVuZcMgijt9k3Jq-2zQQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102489                4.102553
# Dd-TkEszFMkSF-vRih51fQ                3.790547                3.790570
# YTdNcIWAt2nEzZ7NY-fniw                3.742178                3.742257
# bTRFge5pRWMh7IoCLn7lBw                4.079579                4.078196
# -w7ww3yW5BHE3TFyj3IHuQ                3.642632                3.642247
#
# business_id             zwkif4XLEDqdEwEgTWLIVQ
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102519
# Dd-TkEszFMkSF-vRih51fQ                3.790566
# YTdNcIWAt2nEzZ7NY-fniw                3.742240
# bTRFge5pRWMh7IoCLn7lBw                4.078464
# -w7ww3yW5BHE3TFyj3IHuQ                3.642341
#
# [5 rows x 2070 columns]

# %%
# simple recommendation system
def simple_recommend(user_id, count):
    df = preds_df_train.T[user_id].sort_values(ascending=False)
    return df.head(count)

# %%
# recommend the top ten restaurants to a user
simple_recommend('yML2P1evj7FrLncIgaFzHw', 10)
# Out:
# business_id
# wzugmCevnXuCMCF4upAf0w    3.934835
# FhgAHo-8--equM8w5UZ41Q    3.788509
# IRIlwpomRvnXvpkeaGaM2A    3.763541
# 46Ld9Qc9nAx_A0jwclNZiw    3.747641
# kKY726bQREexYHHNLK1H7g    3.746923
# _K63HbZBVQSBCvQicQdl-A    3.743300
# JN8s_dgw9nrSzkHnXxNOtg    3.741336
# 9xSwne4GjwZ6Hlzdx2Zszg    3.728956
# y32M2Hkr7GsUqGG6KwOhZw    3.721766
# 58APdML-PG_OD4El2ePTvw    3.716126
# Name: yML2P1evj7FrLncIgaFzHw, dtype: float64

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
# use cosine distances to build a cosine similarity matrix for the users
user_similarity_train = 1 - pairwise_distances(user_svd_predict(pivot_review_train, df_user_train)[1], metric='cosine')
user_similarity_test = 1 - pairwise_distances(user_svd_predict(pivot_review_test, df_user_test)[1], metric='cosine')

# %%
# use cosine distances to build a business similarity matrix for the businesses
business_similarity_train = 1 - pairwise_distances(business_svd_predict(pivot_review_train.T, df_business_train)[1], metric='cosine')
business_similarity_test = 1 - pairwise_distances(business_svd_predict(pivot_review_test.T, df_business_test)[1], metric='cosine')

# %%
# train user similarity matrix
user_similarity_matrix_train = pd.DataFrame(user_similarity_train, columns=user_id_train, index=user_id_train)
user_similarity_matrix_train.head()
# Out:
# user_id                 Wc5L6iuvSNF5WGBlqIO8nw  Dd-TkEszFMkSF-vRih51fQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                1.000000                0.720741
# Dd-TkEszFMkSF-vRih51fQ                0.720741                1.000000
# YTdNcIWAt2nEzZ7NY-fniw                0.412029                0.531490
# bTRFge5pRWMh7IoCLn7lBw                0.720665                0.693314
# -w7ww3yW5BHE3TFyj3IHuQ                0.913932                0.700075
#
# user_id                 YTdNcIWAt2nEzZ7NY-fniw  bTRFge5pRWMh7IoCLn7lBw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.412029                0.720665
# Dd-TkEszFMkSF-vRih51fQ                0.531490                0.693314
# YTdNcIWAt2nEzZ7NY-fniw                1.000000                0.916873
# bTRFge5pRWMh7IoCLn7lBw                0.916873                1.000000
# -w7ww3yW5BHE3TFyj3IHuQ                0.631012                0.855779
#
# user_id                 -w7ww3yW5BHE3TFyj3IHuQ  4hAauH0dy57uK9o8bCvGUw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.913932                0.815495
# Dd-TkEszFMkSF-vRih51fQ                0.700075                0.830051
# YTdNcIWAt2nEzZ7NY-fniw                0.631012                0.715770
# bTRFge5pRWMh7IoCLn7lBw                0.855779                0.911067
# -w7ww3yW5BHE3TFyj3IHuQ                1.000000                0.826568
#
# user_id                 VMfwMYh8iJapW807Pu1Diw  lKRbcLWDQmOmhcMa3vMCMA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.460906                0.891103
# Dd-TkEszFMkSF-vRih51fQ                0.561576                0.673440
# YTdNcIWAt2nEzZ7NY-fniw                0.959554                0.682519
# bTRFge5pRWMh7IoCLn7lBw                0.896724                0.882128
# -w7ww3yW5BHE3TFyj3IHuQ                0.600692                0.873054
#
# user_id                 2vJ2e51kdbdAmAo_HTr4KQ  9KpMzih4E_gEioFtNeuIIw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.321446                0.128758
# Dd-TkEszFMkSF-vRih51fQ                0.521506                0.113499
# YTdNcIWAt2nEzZ7NY-fniw                0.970352                0.104116
# bTRFge5pRWMh7IoCLn7lBw                0.849233                0.120329
# -w7ww3yW5BHE3TFyj3IHuQ                0.599827               -0.113172
#
# user_id                          ...            v7q2D8s1vsglwQaQcyb8_A  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          0.375954
# Dd-TkEszFMkSF-vRih51fQ           ...                          0.338748
# YTdNcIWAt2nEzZ7NY-fniw           ...                          0.267434
# bTRFge5pRWMh7IoCLn7lBw           ...                          0.306988
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          0.187449
#
# user_id                 hOYNnE3qzb8TDKd3jqvq7Q  LqywrHdM-H8gSdKtGrhBuw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.595463                0.697501
# Dd-TkEszFMkSF-vRih51fQ                0.963002                0.818725
# YTdNcIWAt2nEzZ7NY-fniw                0.422807                0.452622
# bTRFge5pRWMh7IoCLn7lBw                0.563970                0.591316
# -w7ww3yW5BHE3TFyj3IHuQ                0.549721                0.541346
#
# user_id                 iIIbkFd_kgK3n2ewvLstXA  KJIS0INMJKhBmGqFkHMc-A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.289753                0.515562
# Dd-TkEszFMkSF-vRih51fQ                0.829342                0.670527
# YTdNcIWAt2nEzZ7NY-fniw                0.317162                0.909885
# bTRFge5pRWMh7IoCLn7lBw                0.353743                0.919337
# -w7ww3yW5BHE3TFyj3IHuQ                0.209230                0.710060
#
# user_id                 Ih3dwaCS1snsbhS8vRdxHA  LY-KaOJyXzbwZyqjQfl7xA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.015882                0.810667
# Dd-TkEszFMkSF-vRih51fQ               -0.057316                0.808700
# YTdNcIWAt2nEzZ7NY-fniw                0.269327                0.759309
# bTRFge5pRWMh7IoCLn7lBw                0.196887                0.921728
# -w7ww3yW5BHE3TFyj3IHuQ               -0.042394                0.863534
#
# user_id                 e3XuTKzX3w8LP-mEqQgJ9g  awdAcl2dA_WvUPWKOCS1OA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.730153                0.474537
# Dd-TkEszFMkSF-vRih51fQ                0.825599                0.745091
# YTdNcIWAt2nEzZ7NY-fniw                0.313519                0.245549
# bTRFge5pRWMh7IoCLn7lBw                0.570053                0.458413
# -w7ww3yW5BHE3TFyj3IHuQ                0.702391                0.460178
#
# user_id                 0wXvG8Jiu8zdZhvezBgOwA
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.494754
# Dd-TkEszFMkSF-vRih51fQ                0.322130
# YTdNcIWAt2nEzZ7NY-fniw                0.900771
# bTRFge5pRWMh7IoCLn7lBw                0.886281
# -w7ww3yW5BHE3TFyj3IHuQ                0.651209
#
# [5 rows x 3201 columns]

# %%
# test user similarity matrix
user_similarity_matrix_test = pd.DataFrame(user_similarity_test, columns=user_id_test, index=user_id_test)
user_similarity_matrix_test.head()
# Out:
# user_id                 Wc5L6iuvSNF5WGBlqIO8nw  Dd-TkEszFMkSF-vRih51fQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                1.000000                0.792956
# Dd-TkEszFMkSF-vRih51fQ                0.792956                1.000000
# YTdNcIWAt2nEzZ7NY-fniw                0.816564                0.993514
# bTRFge5pRWMh7IoCLn7lBw                0.379237                0.366125
# -w7ww3yW5BHE3TFyj3IHuQ                0.270042                0.308845
#
# user_id                 YTdNcIWAt2nEzZ7NY-fniw  bTRFge5pRWMh7IoCLn7lBw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.816564                0.379237
# Dd-TkEszFMkSF-vRih51fQ                0.993514                0.366125
# YTdNcIWAt2nEzZ7NY-fniw                1.000000                0.373322
# bTRFge5pRWMh7IoCLn7lBw                0.373322                1.000000
# -w7ww3yW5BHE3TFyj3IHuQ                0.264219                0.839735
#
# user_id                 -w7ww3yW5BHE3TFyj3IHuQ  4hAauH0dy57uK9o8bCvGUw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.270042                0.789788
# Dd-TkEszFMkSF-vRih51fQ                0.308845                0.983085
# YTdNcIWAt2nEzZ7NY-fniw                0.264219                0.989574
# bTRFge5pRWMh7IoCLn7lBw                0.839735                0.368340
# -w7ww3yW5BHE3TFyj3IHuQ                1.000000                0.276764
#
# user_id                 VMfwMYh8iJapW807Pu1Diw  lKRbcLWDQmOmhcMa3vMCMA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.794940                0.841365
# Dd-TkEszFMkSF-vRih51fQ                0.981985                0.885230
# YTdNcIWAt2nEzZ7NY-fniw                0.977486                0.913252
# bTRFge5pRWMh7IoCLn7lBw                0.531877                0.521869
# -w7ww3yW5BHE3TFyj3IHuQ                0.456102                0.300552
#
# user_id                 2vJ2e51kdbdAmAo_HTr4KQ  9KpMzih4E_gEioFtNeuIIw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw               -0.042986                0.743116
# Dd-TkEszFMkSF-vRih51fQ               -0.051364                0.898010
# YTdNcIWAt2nEzZ7NY-fniw               -0.036936                0.914095
# bTRFge5pRWMh7IoCLn7lBw                0.250402                0.643674
# -w7ww3yW5BHE3TFyj3IHuQ               -0.040324                0.475806
#
# user_id                          ...            v7q2D8s1vsglwQaQcyb8_A  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          0.824476
# Dd-TkEszFMkSF-vRih51fQ           ...                          0.995281
# YTdNcIWAt2nEzZ7NY-fniw           ...                          0.990583
# bTRFge5pRWMh7IoCLn7lBw           ...                          0.382215
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          0.326871
#
# user_id                 hOYNnE3qzb8TDKd3jqvq7Q  LqywrHdM-H8gSdKtGrhBuw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.537650                0.857398
# Dd-TkEszFMkSF-vRih51fQ                0.790401                0.907546
# YTdNcIWAt2nEzZ7NY-fniw                0.813819                0.913914
# bTRFge5pRWMh7IoCLn7lBw                0.505986                0.478432
# -w7ww3yW5BHE3TFyj3IHuQ                0.305280                0.303664
#
# user_id                 iIIbkFd_kgK3n2ewvLstXA  KJIS0INMJKhBmGqFkHMc-A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.924114                0.890950
# Dd-TkEszFMkSF-vRih51fQ                0.954671                0.811427
# YTdNcIWAt2nEzZ7NY-fniw                0.961988                0.826734
# bTRFge5pRWMh7IoCLn7lBw                0.429181                0.520249
# -w7ww3yW5BHE3TFyj3IHuQ                0.354267                0.466218
#
# user_id                 Ih3dwaCS1snsbhS8vRdxHA  LY-KaOJyXzbwZyqjQfl7xA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.705694                0.786955
# Dd-TkEszFMkSF-vRih51fQ                0.314816                0.701796
# YTdNcIWAt2nEzZ7NY-fniw                0.369758                0.746545
# bTRFge5pRWMh7IoCLn7lBw                0.541035                0.645821
# -w7ww3yW5BHE3TFyj3IHuQ                0.323128                0.345939
#
# user_id                 e3XuTKzX3w8LP-mEqQgJ9g  awdAcl2dA_WvUPWKOCS1OA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.826806                0.828485
# Dd-TkEszFMkSF-vRih51fQ                0.991925                0.656752
# YTdNcIWAt2nEzZ7NY-fniw                0.994725                0.713984
# bTRFge5pRWMh7IoCLn7lBw                0.389246                0.582344
# -w7ww3yW5BHE3TFyj3IHuQ                0.275958                0.315474
#
# user_id                 0wXvG8Jiu8zdZhvezBgOwA
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.865850
# Dd-TkEszFMkSF-vRih51fQ                0.877802
# YTdNcIWAt2nEzZ7NY-fniw                0.904612
# bTRFge5pRWMh7IoCLn7lBw                0.429117
# -w7ww3yW5BHE3TFyj3IHuQ                0.312387
#
# [5 rows x 2800 columns]

# %%
# train business similarity matrix
business_similarity_matrix_train = pd.DataFrame(business_similarity_train, columns=business_id_train, index=business_id_train)
business_similarity_matrix_train.head()
# Out:
# business_id             58APdML-PG_OD4El2ePTvw  8Rdz0VPY8CuT2GQZ7ho2sw  \
# business_id
# 58APdML-PG_OD4El2ePTvw                1.000000                0.604929
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.604929                1.000000
# DAMTCTsSeACXbkSABkhZqQ                0.306082                0.771181
# 6I6uDGwCDggrWXi2T4lfaA                0.684301                0.668666
# qUdGBSFkiPhEL6I718y-Gg                0.534033                0.446506
#
# business_id             DAMTCTsSeACXbkSABkhZqQ  6I6uDGwCDggrWXi2T4lfaA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.306082                0.684301
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.771181                0.668666
# DAMTCTsSeACXbkSABkhZqQ                1.000000                0.602944
# 6I6uDGwCDggrWXi2T4lfaA                0.602944                1.000000
# qUdGBSFkiPhEL6I718y-Gg                0.192602                0.601799
#
# business_id             qUdGBSFkiPhEL6I718y-Gg  ujcbqs6jZfaESgSLvbjWuQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.534033                0.562720
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.446506                0.806925
# DAMTCTsSeACXbkSABkhZqQ                0.192602                0.909381
# 6I6uDGwCDggrWXi2T4lfaA                0.601799                0.764556
# qUdGBSFkiPhEL6I718y-Gg                1.000000                0.215027
#
# business_id             XjbPr3o-YTsticeavLjTEg  Y22IfhXChXoRp3vKi6QwaQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.524335                0.474005
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.407330                0.237145
# DAMTCTsSeACXbkSABkhZqQ                0.311445                0.273086
# 6I6uDGwCDggrWXi2T4lfaA                0.579640                0.466201
# qUdGBSFkiPhEL6I718y-Gg                0.283366                0.191661
#
# business_id             MhINNBBwzGn4-n_YI67wog  OLg1IeS-QxZgNprQ4Hg9gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.543050                0.687466
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.190323                0.863641
# DAMTCTsSeACXbkSABkhZqQ               -0.225258                0.532435
# 6I6uDGwCDggrWXi2T4lfaA                0.330502                0.823990
# qUdGBSFkiPhEL6I718y-Gg                0.680100                0.482624
#
# business_id                      ...            LLBmqBunk40IHdHH_QfjkA  \
# business_id                      ...
# 58APdML-PG_OD4El2ePTvw           ...                          0.869826
# 8Rdz0VPY8CuT2GQZ7ho2sw           ...                          0.625452
# DAMTCTsSeACXbkSABkhZqQ           ...                          0.507281
# 6I6uDGwCDggrWXi2T4lfaA           ...                          0.905221
# qUdGBSFkiPhEL6I718y-Gg           ...                          0.702884
#
# business_id             -ZHeHh4bwLlecbcAD7fTqw  SnD7fcwR4NR7Cgtx7Qm4ZQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.768017               -0.103955
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.585623                0.172381
# DAMTCTsSeACXbkSABkhZqQ                0.601425                0.140032
# 6I6uDGwCDggrWXi2T4lfaA                0.948628                0.225421
# qUdGBSFkiPhEL6I718y-Gg                0.575249                0.144105
#
# business_id             ml7HQlaAcszdBZZHljvYgg  Y5I-z2S3Eeno6cDyn0e6Cg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.787516                0.251441
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.678374                0.591647
# DAMTCTsSeACXbkSABkhZqQ                0.577847                0.582765
# 6I6uDGwCDggrWXi2T4lfaA                0.931421                0.803133
# qUdGBSFkiPhEL6I718y-Gg                0.644695                0.478036
#
# business_id             ODZLMTbjCnpDNkW1JbMjlQ  kWDAdT4m3vbnmE0CgLs4gA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.146670                0.373930
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.155667                0.813378
# DAMTCTsSeACXbkSABkhZqQ                0.133754                0.715401
# 6I6uDGwCDggrWXi2T4lfaA                0.177240                0.568698
# qUdGBSFkiPhEL6I718y-Gg               -0.127833                0.296017
#
# business_id             rofWaZTIuaedAxT_UKleSw  bYfEp3NMskYfEzWL8tVb4w  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.649073                0.811284
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.515024                0.721343
# DAMTCTsSeACXbkSABkhZqQ                0.037360                0.430301
# 6I6uDGwCDggrWXi2T4lfaA                0.372070                0.904395
# qUdGBSFkiPhEL6I718y-Gg                0.236424                0.727604
#
# business_id             HzUxQ1WpeNmeecXN-HPlPw
# business_id
# 58APdML-PG_OD4El2ePTvw                0.559290
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.824730
# DAMTCTsSeACXbkSABkhZqQ                0.808834
# 6I6uDGwCDggrWXi2T4lfaA                0.768868
# qUdGBSFkiPhEL6I718y-Gg                0.681321
#
# [5 rows x 2429 columns]

# %%
# test business similarity matrix
business_similarity_matrix_test = pd.DataFrame(business_similarity_test, columns=business_id_test, index=business_id_test)
business_similarity_matrix_test.head()
# Out:
# business_id             58APdML-PG_OD4El2ePTvw  DAMTCTsSeACXbkSABkhZqQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                1.000000                0.178899
# DAMTCTsSeACXbkSABkhZqQ                0.178899                1.000000
# 6I6uDGwCDggrWXi2T4lfaA                0.951031                0.210156
# qUdGBSFkiPhEL6I718y-Gg                0.691397                0.657375
# ujcbqs6jZfaESgSLvbjWuQ                0.259757                0.310377
#
# business_id             6I6uDGwCDggrWXi2T4lfaA  qUdGBSFkiPhEL6I718y-Gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.951031                0.691397
# DAMTCTsSeACXbkSABkhZqQ                0.210156                0.657375
# 6I6uDGwCDggrWXi2T4lfaA                1.000000                0.749799
# qUdGBSFkiPhEL6I718y-Gg                0.749799                1.000000
# ujcbqs6jZfaESgSLvbjWuQ                0.151422                0.193305
#
# business_id             ujcbqs6jZfaESgSLvbjWuQ  Y22IfhXChXoRp3vKi6QwaQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.259757                0.940552
# DAMTCTsSeACXbkSABkhZqQ                0.310377                0.164341
# 6I6uDGwCDggrWXi2T4lfaA                0.151422                0.900130
# qUdGBSFkiPhEL6I718y-Gg                0.193305                0.649815
# ujcbqs6jZfaESgSLvbjWuQ                1.000000                0.164879
#
# business_id             MhINNBBwzGn4-n_YI67wog  OLg1IeS-QxZgNprQ4Hg9gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.816696                0.776824
# DAMTCTsSeACXbkSABkhZqQ                0.301864                0.461970
# 6I6uDGwCDggrWXi2T4lfaA                0.774837                0.741639
# qUdGBSFkiPhEL6I718y-Gg                0.592183                0.545754
# ujcbqs6jZfaESgSLvbjWuQ                0.139443                0.592555
#
# business_id             DwJlGxAJvohbDR_5jV-ERA  i5j3FrxdR224KIjfv8x2CQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.535893                0.260423
# DAMTCTsSeACXbkSABkhZqQ                0.494442                0.645157
# 6I6uDGwCDggrWXi2T4lfaA                0.504730                0.219069
# qUdGBSFkiPhEL6I718y-Gg                0.660185                0.520032
# ujcbqs6jZfaESgSLvbjWuQ                0.200928                0.207123
#
# business_id                      ...            3uu5jvP5JKdSUW9jk-HO7A  \
# business_id                      ...
# 58APdML-PG_OD4El2ePTvw           ...                         -0.007849
# DAMTCTsSeACXbkSABkhZqQ           ...                          0.623212
# 6I6uDGwCDggrWXi2T4lfaA           ...                         -0.052070
# qUdGBSFkiPhEL6I718y-Gg           ...                          0.320945
# ujcbqs6jZfaESgSLvbjWuQ           ...                         -0.063087
#
# business_id             Akhq4AKxKRDPa6BHpiSEVQ  LLBmqBunk40IHdHH_QfjkA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.824773                0.390546
# DAMTCTsSeACXbkSABkhZqQ                0.415439                0.526627
# 6I6uDGwCDggrWXi2T4lfaA                0.696736                0.268463
# qUdGBSFkiPhEL6I718y-Gg                0.654766                0.337880
# ujcbqs6jZfaESgSLvbjWuQ                0.316322                0.884324
#
# business_id             -ZHeHh4bwLlecbcAD7fTqw  SnD7fcwR4NR7Cgtx7Qm4ZQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.062772                0.329732
# DAMTCTsSeACXbkSABkhZqQ                0.370224                0.874367
# 6I6uDGwCDggrWXi2T4lfaA               -0.109877                0.366669
# qUdGBSFkiPhEL6I718y-Gg                0.193709                0.740265
# ujcbqs6jZfaESgSLvbjWuQ                0.251879                0.063906
#
# business_id             ml7HQlaAcszdBZZHljvYgg  Y5I-z2S3Eeno6cDyn0e6Cg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.578336                0.915200
# DAMTCTsSeACXbkSABkhZqQ                0.416135                0.267851
# 6I6uDGwCDggrWXi2T4lfaA                0.718121                0.814460
# qUdGBSFkiPhEL6I718y-Gg                0.487023                0.675719
# ujcbqs6jZfaESgSLvbjWuQ                0.038891                0.210878
#
# business_id             rofWaZTIuaedAxT_UKleSw  bYfEp3NMskYfEzWL8tVb4w  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.217883                0.971168
# DAMTCTsSeACXbkSABkhZqQ                0.607619                0.164944
# 6I6uDGwCDggrWXi2T4lfaA                0.064799                0.984445
# qUdGBSFkiPhEL6I718y-Gg                0.436975                0.703693
# ujcbqs6jZfaESgSLvbjWuQ                0.226732                0.215547
#
# business_id             HzUxQ1WpeNmeecXN-HPlPw
# business_id
# 58APdML-PG_OD4El2ePTvw                0.982351
# DAMTCTsSeACXbkSABkhZqQ                0.169984
# 6I6uDGwCDggrWXi2T4lfaA                0.990368
# qUdGBSFkiPhEL6I718y-Gg                0.708155
# ujcbqs6jZfaESgSLvbjWuQ                0.201362
#
# [5 rows x 2070 columns]

# %%
# merge datasets
df1 = pd.merge(df_user_train, df_review_train, on='user_id')
df_train_total = pd.merge(df1, df_business_train, on='business_id')

df2 = pd.merge(df_user_test, df_review_test, on='user_id')
df_test_total = pd.merge(df2, df_business_test, on='business_id')

# %%
# create pivot tables
pivot_user_train = df_train_total.pivot(index = 'user_id', columns ='business_id', values = 'average_stars').fillna(0)
pivot_user_test = df_test_total.pivot(index = 'user_id', columns ='business_id', values = 'average_stars').fillna(0)
pivot_business_train = df_train_total.pivot(index = 'user_id', columns ='business_id', values = 'stars_y').fillna(0)
pivot_business_test = df_test_total.pivot(index = 'user_id', columns ='business_id', values = 'stars_y').fillna(0)

# %%
# make a user-business train matrix with train set mean
items_train = df_review_train.shape[0]
total_train = np.sum(df_review_train['stars'])
global_mean_train = total_train / items_train
print(global_mean_train)
pivot_user_train[pivot_user_train != 0] = global_mean_train

# make a user-business test matrix with test set mean
items_test = df_review_test.shape[0]
total_test = np.sum(df_review_test['stars'])
global_mean_test = total_test / items_test
print(global_mean_test)
pivot_user_test[pivot_user_test != 0] = global_mean_test
# Out:
# 3.820671634568857
# 3.8194511314395765

# %%
# predict function to predict the user-user & restaurant-restaurant residuals
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        #You use np.newaxis so that mean_user_rating has same format as ratings
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis])
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'item':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])
    return pred

# %%
# calculate train set residuals using item similarities matrix and restaurant similarities
train_data_matrix = user_svd_predict(pivot_review_train, df_user_train)[1]
item_similarity = pairwise_distances(train_data_matrix.T, metric='cosine')
user_similarity = pairwise_distances(train_data_matrix, metric='cosine')
item_prediction = predict(train_data_matrix, item_similarity, type='item')
user_prediction = predict(train_data_matrix, user_similarity, type='user')

# calculate test set residuals using item similarities matrix and restaurant similarities
test_data_matrix = user_svd_predict(pivot_review_test, df_user_test)[1]
item_similarity_test = pairwise_distances(test_data_matrix.T, metric='cosine')
user_similarity_test = pairwise_distances(test_data_matrix, metric='cosine')
item_prediction_test = predict(test_data_matrix, item_similarity_test, type='item')
user_prediction_test = predict(test_data_matrix, user_similarity_test, type='user')

# %%
# converting dataframes into matrices
pivot_train = pivot_review_train.as_matrix()
pivot_test = pivot_review_test.as_matrix()
pivot_user_train_ = pivot_user_train.as_matrix()
pivot_user_test_ = pivot_user_test.as_matrix()
pivot_business_train_ = pivot_business_train.as_matrix()
pivot_business_test_ = pivot_business_test.as_matrix()

# %%
# predict on train set: add the item-item & restaurant-restaurant residuals to the train set mean rating
pivot_pred_train = np.add(item_prediction, pivot_user_train_)
pivot_pred_train = np.add(pivot_pred_train, user_prediction)

# predict on trest set: add the item-item & restaurant-restaurant residuals to the test set mean rating
pivot_pred_test = np.add(item_prediction_test, pivot_user_test_)
pivot_pred_test = np.add(pivot_pred_test, user_prediction_test)

# %%
# calculate RMSE for test and train set
print("CF Train RMSE score is {}".format(cf_rmse(pivot_train, pivot_pred_train)))
print("CF Test RMSE score is {}".format(cf_rmse(pivot_test, pivot_pred_test)))
# Out:
# CF Train RMSE score is 0.09213448455145726
# CF Test RMSE score is 0.05653953923441608
