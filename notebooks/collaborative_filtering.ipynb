# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegressionCV
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def cf_rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten()
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
df_review_train = pd.read_csv("Montreal_review_train.csv")
df_review_test = pd.read_csv("Montreal_review_test.csv")
df_user_train = pd.read_csv("Montreal_user_train.csv")
df_user_test = pd.read_csv("Montreal_user_test.csv")
df_business_train = pd.read_csv("Montreal_business_train.csv")
df_business_test = pd.read_csv("Montreal_business_test.csv")

# %%
df_user_train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  average_stars  compliment_cool  compliment_cute  \
# 0           0            10           4.10             1302               41
# 1           1            13           3.79             1139               87
# 2           2            37           3.74              129                2
# 3           3           110           4.07               60                1
# 4           4           117           3.64               23                2
#
#    compliment_funny  compliment_hot  compliment_list  compliment_more  \
# 0              1302             806               20               46
# 1              1139             782               54              103
# 2               129              77                6               12
# 3                60              51                1               16
# 4                23              31                0                3
#
#    compliment_note     ...       \
# 0              725     ...
# 1              391     ...
# 2               56     ...
# 3               19     ...
# 4               13     ...
#
#                                               elite  fans  \
# 0        [2016, 2014, 2015, 2017, 2012, 2011, 2013]   435
# 1  [2012, 2008, 2009, 2010, 2007, 2006, 2013, 2011]   198
# 2        [2017, 2016, 2012, 2014, 2015, 2011, 2013]    68
# 3        [2014, 2012, 2015, 2011, 2013, 2016, 2017]    33
# 4                                      [2012, 2013]    15
#
#                                              friends  funny      name  \
# 0  ['xRYvFaMGWsvKcLCFtRIzWQ', 'zvQ7B3KZuFOX7pYLsO...   4880      Risa
# 1  ['KOwp5RDbm7cDyrdXN8FVQQ', '7MlH7OevWSkenMyKFI...  10715     Holly
# 2  ['Cq8uhBLRO1T9l-9R9OmddQ', 'x3_b9Rv-GZpjtCDLqg...    105      Jeff
# 3  ['8s7UH21vFgkRJAJg2L8VzA', 'HWGrt1MEXlzZ71NGx0...      9   Cecille
# 4  ['G-Hav6XBWPEyzI-0nNpdxw', 'EgqsK7MUgqpbaTVZAv...     36  Carolina
#
#   review_count  useful                 user_id  yelping_since elite_status
# 0         1122   26395  Wc5L6iuvSNF5WGBlqIO8nw     2011-07-30          Yes
# 1          698   24047  Dd-TkEszFMkSF-vRih51fQ     2006-07-03          Yes
# 2          754     151  YTdNcIWAt2nEzZ7NY-fniw     2011-05-16          Yes
# 3          356      36  bTRFge5pRWMh7IoCLn7lBw     2007-08-03          Yes
# 4          115      89  -w7ww3yW5BHE3TFyj3IHuQ     2010-06-29          Yes
#
# [5 rows x 25 columns]

# %%
# checking dimensions and unique users before fitting the model
# count number of unique reviews
print(df_review_train.shape)
print(len(df_review_train['user_id'].unique()))
print(len(df_review_train['business_id'].unique()))

# count number of uniqe users
print(df_user_train.shape)
print(len(df_user_train['user_id'].unique()))

# count number of uniqe business
print(df_business_train.shape)
print(len(df_business_train['business_id'].unique()))
# Out:
# (30999, 11)
# 3201
# 2429
# (3201, 25)
# 3201
# (2429, 18)
# 2429

# %%
df_review_train.shape
# Out:
# (30999, 11)

# %%
# creating a user/restaurant pivot table
pivot_review_train = df_review_train.pivot(index = 'user_id', columns ='business_id', values = 'stars').fillna(0)
pivot_review_test = df_review_test.pivot(index = 'user_id', columns ='business_id', values = 'stars').fillna(0)

# %%
pivot_review_train.shape
# Out:
# (3201, 2429)

# %%
from scipy.sparse.linalg import svds

# %%
# Singular Value Decomposition (SVD) for users
def user_svd_predict(df, df_):
    R = df.as_matrix()
    user_ratings_mean = np.mean(R, axis = 1)
    R_demeaned = R - user_ratings_mean.reshape(-1, 1)
    
    U = []
    sigma = []
    Vt = []
    U, sigma, Vt = svds(R_demeaned, k=20)
    sigma = np.diag(sigma)
    all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    average_rating = list(df_['average_stars'])
    average_rating = np.array(average_rating).reshape(-1, 1)
    average_rating = np.repeat(average_rating, all_user_predicted_ratings.shape[1], axis=1)
    all_user_predicted_ratings_total = all_user_predicted_ratings + average_rating
    return (all_user_predicted_ratings_total, all_user_predicted_ratings)

# %%
# Singular Value Decomposition (SVD) for business
def business_svd_predict(df, df_):
    R = df.as_matrix()
    user_ratings_mean = np.mean(R, axis = 1)
    R_demeaned = R - user_ratings_mean.reshape(-1, 1)
    
    U = []
    sigma = []
    Vt = []
    U, sigma, Vt = svds(R_demeaned, k=20)
    sigma = np.diag(sigma)
    all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    average_rating = list(df_['stars'])
    average_rating = np.array(average_rating).reshape(-1, 1)
    average_rating = np.repeat(average_rating, all_user_predicted_ratings.shape[1], axis=1)
    all_user_predicted_ratings_total = all_user_predicted_ratings + average_rating
    return (all_user_predicted_ratings_total, all_user_predicted_ratings)

# %%
all_user_predicted_ratings_total = user_svd_predict(pivot_review_train, df_user_train)[0]
all_user_predicted_ratings_total_test = user_svd_predict(pivot_review_test, df_user_test)[0]
all_business_predicted_ratings_total = business_svd_predict(pivot_review_train.T, df_business_train)[0]
all_business_predicted_ratings_total_test = business_svd_predict(pivot_review_test.T, df_business_test)[0]

# %%
pivot_review_train.shape
# Out:
# (3201, 2429)

# %%
df_user_train.shape
# Out:
# (3201, 25)

# %%
user_id_train = df_user_train['user_id']
user_id_test = df_user_test['user_id']

business_id_train = df_business_train['business_id']
business_id_test = df_business_test['business_id']

# %%
preds_df_train = pd.DataFrame(all_user_predicted_ratings_total, columns=pivot_review_train.columns, index=user_id_train)
preds_df_train.head()
# Out:
# business_id             -0uEqc2vw1xXtuI_r1xTNg  -1xuC540Nycht_iWFeJ-dw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.111058                3.765381
# Dd-TkEszFMkSF-vRih51fQ                3.792130                3.907054
# YTdNcIWAt2nEzZ7NY-fniw                3.750744                3.878034
# bTRFge5pRWMh7IoCLn7lBw                4.115649                4.236376
# -w7ww3yW5BHE3TFyj3IHuQ                3.639676                3.640164
#
# business_id             -7bRnaHp7OHz8KW-THqP4w  -92cC6-X87HQ1DE1UHOx3w  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.079379                4.128996
# Dd-TkEszFMkSF-vRih51fQ                3.789752                3.762797
# YTdNcIWAt2nEzZ7NY-fniw                3.753158                3.769249
# bTRFge5pRWMh7IoCLn7lBw                4.113031                4.187895
# -w7ww3yW5BHE3TFyj3IHuQ                3.643093                3.701733
#
# business_id             -AgfhwHOYrsPKt-_xV_Ipg  -BPHhtX6zzI59IX7ZY-AQA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.074044                4.113905
# Dd-TkEszFMkSF-vRih51fQ                3.788838                3.810440
# YTdNcIWAt2nEzZ7NY-fniw                3.752987                3.731422
# bTRFge5pRWMh7IoCLn7lBw                4.109432                4.201939
# -w7ww3yW5BHE3TFyj3IHuQ                3.621803                3.658139
#
# business_id             -FDkvLmwaBrtVgYFqEWeWA  -FPc3kwUU9GTDd4LzurvTQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.090428                4.105445
# Dd-TkEszFMkSF-vRih51fQ                3.798067                3.790774
# YTdNcIWAt2nEzZ7NY-fniw                3.747570                3.749814
# bTRFge5pRWMh7IoCLn7lBw                4.100459                4.078761
# -w7ww3yW5BHE3TFyj3IHuQ                3.634003                3.638492
#
# business_id             -GHqz1jGYzAtn27CeHeWeA  -HsqnPAz374YSoyFDyjl3A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.112865                4.236941
# Dd-TkEszFMkSF-vRih51fQ                3.802109                3.839521
# YTdNcIWAt2nEzZ7NY-fniw                3.742257                3.729388
# bTRFge5pRWMh7IoCLn7lBw                4.103681                4.439442
# -w7ww3yW5BHE3TFyj3IHuQ                3.636034                3.699485
#
# business_id                      ...            zqV3T9HltH1pmlRFJJSFcA  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          4.072490
# Dd-TkEszFMkSF-vRih51fQ           ...                          3.788810
# YTdNcIWAt2nEzZ7NY-fniw           ...                          3.763453
# bTRFge5pRWMh7IoCLn7lBw           ...                          4.131304
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          3.646045
#
# business_id             zr2wA55AskfBJxrvUeDZRA  zrnP9HqoF-RI9jqoW8pytA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.138484                4.098128
# Dd-TkEszFMkSF-vRih51fQ                3.806899                3.794853
# YTdNcIWAt2nEzZ7NY-fniw                3.765689                3.747911
# bTRFge5pRWMh7IoCLn7lBw                4.116208                4.090716
# -w7ww3yW5BHE3TFyj3IHuQ                3.635107                3.640433
#
# business_id             zsMMlOYtXm8SNy0bl1leBA  zsbsLCO-bw3gdNE9XNgBYw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.177040                4.119881
# Dd-TkEszFMkSF-vRih51fQ                3.772085                3.803739
# YTdNcIWAt2nEzZ7NY-fniw                3.749756                3.746374
# bTRFge5pRWMh7IoCLn7lBw                4.198155                4.069027
# -w7ww3yW5BHE3TFyj3IHuQ                3.654267                3.620071
#
# business_id             zv92BYJH09YjFQOtSyYp-A  zwBEMcCVqh8wOXn_sOIfxg  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.092555                4.095933
# Dd-TkEszFMkSF-vRih51fQ                3.794808                3.817778
# YTdNcIWAt2nEzZ7NY-fniw                3.748165                3.732125
# bTRFge5pRWMh7IoCLn7lBw                4.081443                4.195563
# -w7ww3yW5BHE3TFyj3IHuQ                3.637269                3.671494
#
# business_id             zwgVuZcMgijt9k3Jq-2zQQ  zwkif4XLEDqdEwEgTWLIVQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.094899                4.219485
# Dd-TkEszFMkSF-vRih51fQ                3.795181                3.762455
# YTdNcIWAt2nEzZ7NY-fniw                3.749004                3.779889
# bTRFge5pRWMh7IoCLn7lBw                4.100826                3.985273
# -w7ww3yW5BHE3TFyj3IHuQ                3.637200                3.682764
#
# business_id             zzjKekzQ6i4iR-qpo405Pw
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.085823
# Dd-TkEszFMkSF-vRih51fQ                3.772413
# YTdNcIWAt2nEzZ7NY-fniw                3.762268
# bTRFge5pRWMh7IoCLn7lBw                4.088402
# -w7ww3yW5BHE3TFyj3IHuQ                3.668489
#
# [5 rows x 2429 columns]

# %%
preds_df_test = pd.DataFrame(all_user_predicted_ratings_total_test, columns=pivot_review_test.columns, index=user_id_test)
preds_df_test.head()
# Out:
# business_id             -0uEqc2vw1xXtuI_r1xTNg  -1xuC540Nycht_iWFeJ-dw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102477                4.249559
# Dd-TkEszFMkSF-vRih51fQ                3.790618                3.788917
# YTdNcIWAt2nEzZ7NY-fniw                3.742174                3.718317
# bTRFge5pRWMh7IoCLn7lBw                4.077589                4.333084
# -w7ww3yW5BHE3TFyj3IHuQ                3.642578                3.688117
#
# business_id             -7bRnaHp7OHz8KW-THqP4w  -92cC6-X87HQ1DE1UHOx3w  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102253                4.101849
# Dd-TkEszFMkSF-vRih51fQ                3.790619                3.790514
# YTdNcIWAt2nEzZ7NY-fniw                3.742233                3.742351
# bTRFge5pRWMh7IoCLn7lBw                4.075519                4.064777
# -w7ww3yW5BHE3TFyj3IHuQ                3.642397                3.645565
#
# business_id             -AgfhwHOYrsPKt-_xV_Ipg  -FDkvLmwaBrtVgYFqEWeWA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.100737                4.102513
# Dd-TkEszFMkSF-vRih51fQ                3.790607                3.790589
# YTdNcIWAt2nEzZ7NY-fniw                3.742031                3.742384
# bTRFge5pRWMh7IoCLn7lBw                4.078651                4.082149
# -w7ww3yW5BHE3TFyj3IHuQ                3.641951                3.642059
#
# business_id             -FPc3kwUU9GTDd4LzurvTQ  -HsqnPAz374YSoyFDyjl3A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.102370                4.102075
# Dd-TkEszFMkSF-vRih51fQ                3.790622                3.790513
# YTdNcIWAt2nEzZ7NY-fniw                3.742243                3.740605
# bTRFge5pRWMh7IoCLn7lBw                4.076959                4.093477
# -w7ww3yW5BHE3TFyj3IHuQ                3.642840                3.642970
#
# business_id             -MwaICRwxaUi0JBfad2Y3Q  -Mz3M0g6iFZczs6a7ddf5g  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.101559                4.102597
# Dd-TkEszFMkSF-vRih51fQ                3.790574                3.790484
# YTdNcIWAt2nEzZ7NY-fniw                3.741719                3.742942
# bTRFge5pRWMh7IoCLn7lBw                4.095684                4.084624
# -w7ww3yW5BHE3TFyj3IHuQ                3.649755                3.640657
#
# business_id                      ...            zktCQRlDtF6XmOpqKBz1mA  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          4.100987
# Dd-TkEszFMkSF-vRih51fQ           ...                          3.790574
# YTdNcIWAt2nEzZ7NY-fniw           ...                          3.740200
# bTRFge5pRWMh7IoCLn7lBw           ...                          4.072748
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          3.644327
#
# business_id             zmQyE-gIUpwBCMmTFFRbJw  zpw5S3QwUse1MH-Eerbnaw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.100863                4.102219
# Dd-TkEszFMkSF-vRih51fQ                3.790609                3.790513
# YTdNcIWAt2nEzZ7NY-fniw                3.742232                3.743492
# bTRFge5pRWMh7IoCLn7lBw                4.078266                4.075081
# -w7ww3yW5BHE3TFyj3IHuQ                3.643082                3.643405
#
# business_id             zqV3T9HltH1pmlRFJJSFcA  zr2wA55AskfBJxrvUeDZRA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.098799                4.105492
# Dd-TkEszFMkSF-vRih51fQ                3.790247                3.790299
# YTdNcIWAt2nEzZ7NY-fniw                3.739589                3.745336
# bTRFge5pRWMh7IoCLn7lBw                4.121961                4.046767
# -w7ww3yW5BHE3TFyj3IHuQ                3.664063                3.646322
#
# business_id             zrnP9HqoF-RI9jqoW8pytA  zsMMlOYtXm8SNy0bl1leBA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.101588                4.101210
# Dd-TkEszFMkSF-vRih51fQ                3.790607                3.790486
# YTdNcIWAt2nEzZ7NY-fniw                3.742487                3.742482
# bTRFge5pRWMh7IoCLn7lBw                4.065211                4.068705
# -w7ww3yW5BHE3TFyj3IHuQ                3.641457                3.644397
#
# business_id             zwBEMcCVqh8wOXn_sOIfxg  zwgVuZcMgijt9k3Jq-2zQQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.098801                4.102365
# Dd-TkEszFMkSF-vRih51fQ                3.790552                3.790628
# YTdNcIWAt2nEzZ7NY-fniw                3.741877                3.742250
# bTRFge5pRWMh7IoCLn7lBw                4.088010                4.077159
# -w7ww3yW5BHE3TFyj3IHuQ                3.642431                3.642516
#
# business_id             zwkif4XLEDqdEwEgTWLIVQ
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                4.101979
# Dd-TkEszFMkSF-vRih51fQ                3.790606
# YTdNcIWAt2nEzZ7NY-fniw                3.742319
# bTRFge5pRWMh7IoCLn7lBw                4.076365
# -w7ww3yW5BHE3TFyj3IHuQ                3.642415
#
# [5 rows x 2070 columns]

# %%
# simple recommendation system
def simple_recommend(user_id, count):
    df = preds_df_train.T[user_id].sort_values(ascending=False)
    return df.head(count)

# %%
# recommend the top ten restaurants to a user
simple_recommend('yML2P1evj7FrLncIgaFzHw', 10)
# Out:
# business_id
# kKY726bQREexYHHNLK1H7g    4.632830
# IRIlwpomRvnXvpkeaGaM2A    4.390620
# mm2wLW24ESxNIEL2bjseaQ    4.201337
# um_o0pxQ3DlRI9EfCzw0hw    4.194907
# 2gUbgbdJ7IFSbicBXlSchw    4.142699
# y32M2Hkr7GsUqGG6KwOhZw    4.079658
# 58APdML-PG_OD4El2ePTvw    4.057295
# FhgAHo-8--equM8w5UZ41Q    4.016346
# JN8s_dgw9nrSzkHnXxNOtg    3.909097
# s2I_Ni76bjJNK9yG60iD-Q    3.902061
# Name: yML2P1evj7FrLncIgaFzHw, dtype: float64

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
# use cosine distances to build a cosine similarity matrix for the users
user_similarity_train = 1 - pairwise_distances(user_svd_predict(pivot_review_train, df_user_train)[1], metric='cosine')
user_similarity_test = 1 - pairwise_distances(user_svd_predict(pivot_review_test, df_user_test)[1], metric='cosine')

# %%
# use cosine distances to build a business similarity matrix for the businesses
business_similarity_train = 1 - pairwise_distances(business_svd_predict(pivot_review_train.T, df_business_train)[1], metric='cosine')
business_similarity_test = 1 - pairwise_distances(business_svd_predict(pivot_review_test.T, df_business_test)[1], metric='cosine')

# %%
# train user similarity matrix
user_similarity_matrix_train = pd.DataFrame(user_similarity_train, columns=user_id_train, index=user_id_train)
user_similarity_matrix_train.head()
# Out:
# user_id                 Wc5L6iuvSNF5WGBlqIO8nw  Dd-TkEszFMkSF-vRih51fQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                1.000000                0.123739
# Dd-TkEszFMkSF-vRih51fQ                0.123739                1.000000
# YTdNcIWAt2nEzZ7NY-fniw               -0.033120                0.082072
# bTRFge5pRWMh7IoCLn7lBw                0.288995                0.350151
# -w7ww3yW5BHE3TFyj3IHuQ                0.581747                0.107605
#
# user_id                 YTdNcIWAt2nEzZ7NY-fniw  bTRFge5pRWMh7IoCLn7lBw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw               -0.033120                0.288995
# Dd-TkEszFMkSF-vRih51fQ                0.082072                0.350151
# YTdNcIWAt2nEzZ7NY-fniw                1.000000                0.057411
# bTRFge5pRWMh7IoCLn7lBw                0.057411                1.000000
# -w7ww3yW5BHE3TFyj3IHuQ                0.078848                0.378264
#
# user_id                 -w7ww3yW5BHE3TFyj3IHuQ  4hAauH0dy57uK9o8bCvGUw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.581747                0.137748
# Dd-TkEszFMkSF-vRih51fQ                0.107605                0.043687
# YTdNcIWAt2nEzZ7NY-fniw                0.078848                0.348380
# bTRFge5pRWMh7IoCLn7lBw                0.378264                0.021736
# -w7ww3yW5BHE3TFyj3IHuQ                1.000000               -0.207281
#
# user_id                 VMfwMYh8iJapW807Pu1Diw  lKRbcLWDQmOmhcMa3vMCMA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.093395                0.367794
# Dd-TkEszFMkSF-vRih51fQ                0.261767               -0.083328
# YTdNcIWAt2nEzZ7NY-fniw                0.474439                0.275562
# bTRFge5pRWMh7IoCLn7lBw                0.323239                0.408859
# -w7ww3yW5BHE3TFyj3IHuQ                0.115763                0.133768
#
# user_id                 2vJ2e51kdbdAmAo_HTr4KQ  9KpMzih4E_gEioFtNeuIIw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.107102               -0.062889
# Dd-TkEszFMkSF-vRih51fQ               -0.021795                0.186220
# YTdNcIWAt2nEzZ7NY-fniw                0.461942                0.127301
# bTRFge5pRWMh7IoCLn7lBw                0.279707                0.094915
# -w7ww3yW5BHE3TFyj3IHuQ                0.536527                0.002525
#
# user_id                          ...            v7q2D8s1vsglwQaQcyb8_A  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          0.317822
# Dd-TkEszFMkSF-vRih51fQ           ...                          0.108294
# YTdNcIWAt2nEzZ7NY-fniw           ...                         -0.010050
# bTRFge5pRWMh7IoCLn7lBw           ...                          0.140430
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          0.090438
#
# user_id                 hOYNnE3qzb8TDKd3jqvq7Q  LqywrHdM-H8gSdKtGrhBuw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.267291                0.089310
# Dd-TkEszFMkSF-vRih51fQ                0.242365                0.253467
# YTdNcIWAt2nEzZ7NY-fniw                0.215982               -0.109354
# bTRFge5pRWMh7IoCLn7lBw               -0.173267                0.514292
# -w7ww3yW5BHE3TFyj3IHuQ               -0.006708                0.176181
#
# user_id                 iIIbkFd_kgK3n2ewvLstXA  KJIS0INMJKhBmGqFkHMc-A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.074979                0.187363
# Dd-TkEszFMkSF-vRih51fQ                0.053828                0.244121
# YTdNcIWAt2nEzZ7NY-fniw                0.237667                0.423541
# bTRFge5pRWMh7IoCLn7lBw                0.148501                0.373318
# -w7ww3yW5BHE3TFyj3IHuQ               -0.010482                0.351390
#
# user_id                 Ih3dwaCS1snsbhS8vRdxHA  LY-KaOJyXzbwZyqjQfl7xA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw               -0.049799                0.018654
# Dd-TkEszFMkSF-vRih51fQ               -0.036538                0.265373
# YTdNcIWAt2nEzZ7NY-fniw                0.186048                0.425421
# bTRFge5pRWMh7IoCLn7lBw                0.159174                0.036335
# -w7ww3yW5BHE3TFyj3IHuQ               -0.071426                0.141043
#
# user_id                 e3XuTKzX3w8LP-mEqQgJ9g  awdAcl2dA_WvUPWKOCS1OA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.126737                0.120642
# Dd-TkEszFMkSF-vRih51fQ                0.397636                0.114079
# YTdNcIWAt2nEzZ7NY-fniw                0.331947                0.043822
# bTRFge5pRWMh7IoCLn7lBw                0.105005                0.271699
# -w7ww3yW5BHE3TFyj3IHuQ                0.097905                0.579939
#
# user_id                 0wXvG8Jiu8zdZhvezBgOwA
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.096226
# Dd-TkEszFMkSF-vRih51fQ               -0.098947
# YTdNcIWAt2nEzZ7NY-fniw                0.423622
# bTRFge5pRWMh7IoCLn7lBw                0.127442
# -w7ww3yW5BHE3TFyj3IHuQ               -0.221361
#
# [5 rows x 3201 columns]

# %%
# test user similarity matrix
user_similarity_matrix_test = pd.DataFrame(user_similarity_test, columns=user_id_test, index=user_id_test)
user_similarity_matrix_test.head()
# Out:
# user_id                 Wc5L6iuvSNF5WGBlqIO8nw  Dd-TkEszFMkSF-vRih51fQ  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                1.000000                0.273028
# Dd-TkEszFMkSF-vRih51fQ                0.273028                1.000000
# YTdNcIWAt2nEzZ7NY-fniw                0.029052                0.756588
# bTRFge5pRWMh7IoCLn7lBw                0.184856                0.152833
# -w7ww3yW5BHE3TFyj3IHuQ                0.024051                0.264246
#
# user_id                 YTdNcIWAt2nEzZ7NY-fniw  bTRFge5pRWMh7IoCLn7lBw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.029052                0.184856
# Dd-TkEszFMkSF-vRih51fQ                0.756588                0.152833
# YTdNcIWAt2nEzZ7NY-fniw                1.000000                0.144151
# bTRFge5pRWMh7IoCLn7lBw                0.144151                1.000000
# -w7ww3yW5BHE3TFyj3IHuQ                0.128624                0.342405
#
# user_id                 -w7ww3yW5BHE3TFyj3IHuQ  4hAauH0dy57uK9o8bCvGUw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.024051                0.461267
# Dd-TkEszFMkSF-vRih51fQ                0.264246                0.858565
# YTdNcIWAt2nEzZ7NY-fniw                0.128624                0.711422
# bTRFge5pRWMh7IoCLn7lBw                0.342405                0.138795
# -w7ww3yW5BHE3TFyj3IHuQ                1.000000                0.218998
#
# user_id                 VMfwMYh8iJapW807Pu1Diw  lKRbcLWDQmOmhcMa3vMCMA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.180832               -0.215365
# Dd-TkEszFMkSF-vRih51fQ                0.570801                0.283083
# YTdNcIWAt2nEzZ7NY-fniw                0.576731                0.552788
# bTRFge5pRWMh7IoCLn7lBw                0.421830                0.194041
# -w7ww3yW5BHE3TFyj3IHuQ                0.527180               -0.051809
#
# user_id                 2vJ2e51kdbdAmAo_HTr4KQ  9KpMzih4E_gEioFtNeuIIw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw               -0.025200                0.160955
# Dd-TkEszFMkSF-vRih51fQ               -0.025041                0.529752
# YTdNcIWAt2nEzZ7NY-fniw               -0.020392                0.799825
# bTRFge5pRWMh7IoCLn7lBw                0.101054                0.136212
# -w7ww3yW5BHE3TFyj3IHuQ               -0.016700                0.247150
#
# user_id                          ...            v7q2D8s1vsglwQaQcyb8_A  \
# user_id                          ...
# Wc5L6iuvSNF5WGBlqIO8nw           ...                          0.234125
# Dd-TkEszFMkSF-vRih51fQ           ...                          0.934899
# YTdNcIWAt2nEzZ7NY-fniw           ...                          0.787761
# bTRFge5pRWMh7IoCLn7lBw           ...                          0.246640
# -w7ww3yW5BHE3TFyj3IHuQ           ...                          0.235919
#
# user_id                 hOYNnE3qzb8TDKd3jqvq7Q  LqywrHdM-H8gSdKtGrhBuw  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw               -0.125812                0.262517
# Dd-TkEszFMkSF-vRih51fQ                0.572209                0.580154
# YTdNcIWAt2nEzZ7NY-fniw                0.504840                0.515459
# bTRFge5pRWMh7IoCLn7lBw                0.014915                0.265498
# -w7ww3yW5BHE3TFyj3IHuQ                0.186573                0.156075
#
# user_id                 iIIbkFd_kgK3n2ewvLstXA  KJIS0INMJKhBmGqFkHMc-A  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.101626                0.191844
# Dd-TkEszFMkSF-vRih51fQ                0.787125                0.327144
# YTdNcIWAt2nEzZ7NY-fniw                0.643395                0.443141
# bTRFge5pRWMh7IoCLn7lBw                0.147580                0.369932
# -w7ww3yW5BHE3TFyj3IHuQ                0.305037                0.159912
#
# user_id                 Ih3dwaCS1snsbhS8vRdxHA  LY-KaOJyXzbwZyqjQfl7xA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.252877               -0.068769
# Dd-TkEszFMkSF-vRih51fQ               -0.019333                0.120580
# YTdNcIWAt2nEzZ7NY-fniw                0.199837                0.492037
# bTRFge5pRWMh7IoCLn7lBw                0.225324               -0.008432
# -w7ww3yW5BHE3TFyj3IHuQ               -0.208084               -0.007545
#
# user_id                 e3XuTKzX3w8LP-mEqQgJ9g  awdAcl2dA_WvUPWKOCS1OA  \
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.252614               -0.127824
# Dd-TkEszFMkSF-vRih51fQ                0.962273                0.103892
# YTdNcIWAt2nEzZ7NY-fniw                0.668754                0.193777
# bTRFge5pRWMh7IoCLn7lBw                0.081523               -0.241318
# -w7ww3yW5BHE3TFyj3IHuQ                0.276780                0.130077
#
# user_id                 0wXvG8Jiu8zdZhvezBgOwA
# user_id
# Wc5L6iuvSNF5WGBlqIO8nw                0.112969
# Dd-TkEszFMkSF-vRih51fQ                0.289312
# YTdNcIWAt2nEzZ7NY-fniw                0.227147
# bTRFge5pRWMh7IoCLn7lBw               -0.066618
# -w7ww3yW5BHE3TFyj3IHuQ                0.028004
#
# [5 rows x 2800 columns]

# %%
# train business similarity matrix
business_similarity_matrix_train = pd.DataFrame(business_similarity_train, columns=business_id_train, index=business_id_train)
business_similarity_matrix_train.head()
# Out:
# business_id             58APdML-PG_OD4El2ePTvw  8Rdz0VPY8CuT2GQZ7ho2sw  \
# business_id
# 58APdML-PG_OD4El2ePTvw                1.000000                0.271844
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.271844                1.000000
# DAMTCTsSeACXbkSABkhZqQ                0.079825               -0.060567
# 6I6uDGwCDggrWXi2T4lfaA                0.428932                0.191821
# qUdGBSFkiPhEL6I718y-Gg                0.314548                0.296899
#
# business_id             DAMTCTsSeACXbkSABkhZqQ  6I6uDGwCDggrWXi2T4lfaA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.079825                0.428932
# 8Rdz0VPY8CuT2GQZ7ho2sw               -0.060567                0.191821
# DAMTCTsSeACXbkSABkhZqQ                1.000000                0.344558
# 6I6uDGwCDggrWXi2T4lfaA                0.344558                1.000000
# qUdGBSFkiPhEL6I718y-Gg                0.041525                0.566044
#
# business_id             qUdGBSFkiPhEL6I718y-Gg  ujcbqs6jZfaESgSLvbjWuQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.314548                0.304685
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.296899                0.099059
# DAMTCTsSeACXbkSABkhZqQ                0.041525                0.080128
# 6I6uDGwCDggrWXi2T4lfaA                0.566044                0.147380
# qUdGBSFkiPhEL6I718y-Gg                1.000000               -0.030378
#
# business_id             XjbPr3o-YTsticeavLjTEg  Y22IfhXChXoRp3vKi6QwaQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.176533                0.329332
# 8Rdz0VPY8CuT2GQZ7ho2sw               -0.033960                0.052488
# DAMTCTsSeACXbkSABkhZqQ               -0.008973               -0.141186
# 6I6uDGwCDggrWXi2T4lfaA                0.233676                0.181992
# qUdGBSFkiPhEL6I718y-Gg                0.244858                0.121635
#
# business_id             MhINNBBwzGn4-n_YI67wog  OLg1IeS-QxZgNprQ4Hg9gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.320960                0.537847
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.032706                0.248680
# DAMTCTsSeACXbkSABkhZqQ               -0.304736                0.151596
# 6I6uDGwCDggrWXi2T4lfaA                0.093687                0.269127
# qUdGBSFkiPhEL6I718y-Gg                0.357527                0.103237
#
# business_id                      ...            LLBmqBunk40IHdHH_QfjkA  \
# business_id                      ...
# 58APdML-PG_OD4El2ePTvw           ...                          0.283587
# 8Rdz0VPY8CuT2GQZ7ho2sw           ...                          0.210382
# DAMTCTsSeACXbkSABkhZqQ           ...                          0.302561
# 6I6uDGwCDggrWXi2T4lfaA           ...                          0.281470
# qUdGBSFkiPhEL6I718y-Gg           ...                          0.363627
#
# business_id             -ZHeHh4bwLlecbcAD7fTqw  SnD7fcwR4NR7Cgtx7Qm4ZQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.349941                0.018316
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.143372               -0.075271
# DAMTCTsSeACXbkSABkhZqQ                0.119427                0.007250
# 6I6uDGwCDggrWXi2T4lfaA                0.342534                0.178220
# qUdGBSFkiPhEL6I718y-Gg                0.323686                0.165245
#
# business_id             ml7HQlaAcszdBZZHljvYgg  Y5I-z2S3Eeno6cDyn0e6Cg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.433927                0.185373
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.367880                0.214407
# DAMTCTsSeACXbkSABkhZqQ               -0.082208               -0.231451
# 6I6uDGwCDggrWXi2T4lfaA                0.417244               -0.037037
# qUdGBSFkiPhEL6I718y-Gg                0.420615               -0.010195
#
# business_id             ODZLMTbjCnpDNkW1JbMjlQ  kWDAdT4m3vbnmE0CgLs4gA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.038287               -0.286370
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.050381               -0.001927
# DAMTCTsSeACXbkSABkhZqQ               -0.235235                0.129771
# 6I6uDGwCDggrWXi2T4lfaA               -0.043609                0.100768
# qUdGBSFkiPhEL6I718y-Gg               -0.153927               -0.098615
#
# business_id             rofWaZTIuaedAxT_UKleSw  bYfEp3NMskYfEzWL8tVb4w  \
# business_id
# 58APdML-PG_OD4El2ePTvw               -0.044779                0.350037
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.117788                0.357570
# DAMTCTsSeACXbkSABkhZqQ                0.020775               -0.147551
# 6I6uDGwCDggrWXi2T4lfaA               -0.097680                0.602414
# qUdGBSFkiPhEL6I718y-Gg                0.079447                0.414936
#
# business_id             HzUxQ1WpeNmeecXN-HPlPw
# business_id
# 58APdML-PG_OD4El2ePTvw                0.162044
# 8Rdz0VPY8CuT2GQZ7ho2sw                0.531283
# DAMTCTsSeACXbkSABkhZqQ                0.295134
# 6I6uDGwCDggrWXi2T4lfaA                0.637140
# qUdGBSFkiPhEL6I718y-Gg                0.419869
#
# [5 rows x 2429 columns]

# %%
# test business similarity matrix
business_similarity_matrix_test = pd.DataFrame(business_similarity_test, columns=business_id_test, index=business_id_test)
business_similarity_matrix_test.head()
# Out:
# business_id             58APdML-PG_OD4El2ePTvw  DAMTCTsSeACXbkSABkhZqQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                1.000000               -0.023429
# DAMTCTsSeACXbkSABkhZqQ               -0.023429                1.000000
# 6I6uDGwCDggrWXi2T4lfaA                0.234868                0.013408
# qUdGBSFkiPhEL6I718y-Gg                0.231090               -0.056256
# ujcbqs6jZfaESgSLvbjWuQ                0.091581                0.099845
#
# business_id             6I6uDGwCDggrWXi2T4lfaA  qUdGBSFkiPhEL6I718y-Gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.234868                0.231090
# DAMTCTsSeACXbkSABkhZqQ                0.013408               -0.056256
# 6I6uDGwCDggrWXi2T4lfaA                1.000000                0.023901
# qUdGBSFkiPhEL6I718y-Gg                0.023901                1.000000
# ujcbqs6jZfaESgSLvbjWuQ               -0.007454                0.036277
#
# business_id             ujcbqs6jZfaESgSLvbjWuQ  Y22IfhXChXoRp3vKi6QwaQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.091581                0.490803
# DAMTCTsSeACXbkSABkhZqQ                0.099845               -0.113187
# 6I6uDGwCDggrWXi2T4lfaA               -0.007454                0.240044
# qUdGBSFkiPhEL6I718y-Gg                0.036277                0.230125
# ujcbqs6jZfaESgSLvbjWuQ                1.000000                0.085431
#
# business_id             MhINNBBwzGn4-n_YI67wog  OLg1IeS-QxZgNprQ4Hg9gg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.710535                0.365032
# DAMTCTsSeACXbkSABkhZqQ               -0.060088                0.582035
# 6I6uDGwCDggrWXi2T4lfaA                0.315998                0.516830
# qUdGBSFkiPhEL6I718y-Gg                0.330451                0.077361
# ujcbqs6jZfaESgSLvbjWuQ                0.067322                0.350011
#
# business_id             DwJlGxAJvohbDR_5jV-ERA  i5j3FrxdR224KIjfv8x2CQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.206606                0.239764
# DAMTCTsSeACXbkSABkhZqQ                0.032511               -0.043455
# 6I6uDGwCDggrWXi2T4lfaA               -0.185376                0.057671
# qUdGBSFkiPhEL6I718y-Gg                0.199359                0.448048
# ujcbqs6jZfaESgSLvbjWuQ               -0.409916                0.101035
#
# business_id                      ...            3uu5jvP5JKdSUW9jk-HO7A  \
# business_id                      ...
# 58APdML-PG_OD4El2ePTvw           ...                         -0.105276
# DAMTCTsSeACXbkSABkhZqQ           ...                         -0.017552
# 6I6uDGwCDggrWXi2T4lfaA           ...                         -0.017692
# qUdGBSFkiPhEL6I718y-Gg           ...                         -0.061041
# ujcbqs6jZfaESgSLvbjWuQ           ...                          0.103053
#
# business_id             Akhq4AKxKRDPa6BHpiSEVQ  LLBmqBunk40IHdHH_QfjkA  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.373045                0.028260
# DAMTCTsSeACXbkSABkhZqQ               -0.115553                0.365847
# 6I6uDGwCDggrWXi2T4lfaA                0.178879                0.080482
# qUdGBSFkiPhEL6I718y-Gg                0.359701                0.173053
# ujcbqs6jZfaESgSLvbjWuQ                0.330126                0.238725
#
# business_id             -ZHeHh4bwLlecbcAD7fTqw  SnD7fcwR4NR7Cgtx7Qm4ZQ  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.139765                0.027663
# DAMTCTsSeACXbkSABkhZqQ               -0.009046                0.496379
# 6I6uDGwCDggrWXi2T4lfaA               -0.038698                0.006968
# qUdGBSFkiPhEL6I718y-Gg                0.042803                0.300711
# ujcbqs6jZfaESgSLvbjWuQ                0.149777               -0.080113
#
# business_id             ml7HQlaAcszdBZZHljvYgg  Y5I-z2S3Eeno6cDyn0e6Cg  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.213343                0.297128
# DAMTCTsSeACXbkSABkhZqQ                0.022771               -0.121338
# 6I6uDGwCDggrWXi2T4lfaA                0.828757                0.000083
# qUdGBSFkiPhEL6I718y-Gg                0.026037                0.238533
# ujcbqs6jZfaESgSLvbjWuQ               -0.096041                0.187941
#
# business_id             rofWaZTIuaedAxT_UKleSw  bYfEp3NMskYfEzWL8tVb4w  \
# business_id
# 58APdML-PG_OD4El2ePTvw                0.192612                0.847896
# DAMTCTsSeACXbkSABkhZqQ               -0.001104               -0.041568
# 6I6uDGwCDggrWXi2T4lfaA               -0.022214                0.342843
# qUdGBSFkiPhEL6I718y-Gg               -0.153242                0.378002
# ujcbqs6jZfaESgSLvbjWuQ               -0.123287                0.186262
#
# business_id             HzUxQ1WpeNmeecXN-HPlPw
# business_id
# 58APdML-PG_OD4El2ePTvw                0.792960
# DAMTCTsSeACXbkSABkhZqQ               -0.024040
# 6I6uDGwCDggrWXi2T4lfaA                0.480901
# qUdGBSFkiPhEL6I718y-Gg                0.386268
# ujcbqs6jZfaESgSLvbjWuQ                0.152023
#
# [5 rows x 2070 columns]

# %%
# merge datasets
df1 = pd.merge(df_user_train, df_review_train, on='user_id')
df_train_total = pd.merge(df1, df_business_train, on='business_id')

df2 = pd.merge(df_user_test, df_review_test, on='user_id')
df_test_total = pd.merge(df2, df_business_test, on='business_id')

# %%
# create pivot tables
pivot_user_train = df_train_total.pivot(index = 'user_id', columns ='business_id', values = 'average_stars').fillna(0)
pivot_user_test = df_test_total.pivot(index = 'user_id', columns ='business_id', values = 'average_stars').fillna(0)
pivot_business_train = df_train_total.pivot(index = 'user_id', columns ='business_id', values = 'stars_y').fillna(0)
pivot_business_test = df_test_total.pivot(index = 'user_id', columns ='business_id', values = 'stars_y').fillna(0)

# %%
# make a user-business train matrix with train set mean
items_train = df_review_train.shape[0]
total_train = np.sum(df_review_train['stars'])
global_mean_train = total_train / items_train
print(global_mean_train)
pivot_user_train[pivot_user_train != 0] = global_mean_train

# make a user-business test matrix with test set mean
items_test = df_review_test.shape[0]
total_test = np.sum(df_review_test['stars'])
global_mean_test = total_test / items_test
print(global_mean_test)
pivot_user_test[pivot_user_test != 0] = global_mean_test
# Out:
# 3.820671634568857
# 3.8194511314395765

# %%
# predict function to predict the user-user & restaurant-restaurant residuals
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        #You use np.newaxis so that mean_user_rating has same format as ratings
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis])
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'item':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])
    return pred

# %%
# calculate train set residuals using item similarities matrix and restaurant similarities
train_data_matrix = user_svd_predict(pivot_review_train, df_user_train)[1]
item_similarity = pairwise_distances(train_data_matrix.T, metric='cosine')
user_similarity = pairwise_distances(train_data_matrix, metric='cosine')
item_prediction = predict(train_data_matrix, item_similarity, type='item')
user_prediction = predict(train_data_matrix, user_similarity, type='user')

# calculate test set residuals using item similarities matrix and restaurant similarities
test_data_matrix = user_svd_predict(pivot_review_test, df_user_test)[1]
item_similarity_test = pairwise_distances(test_data_matrix.T, metric='cosine')
user_similarity_test = pairwise_distances(test_data_matrix, metric='cosine')
item_prediction_test = predict(test_data_matrix, item_similarity_test, type='item')
user_prediction_test = predict(test_data_matrix, user_similarity_test, type='user')

# %%
# converting dataframes into matrices
pivot_train = pivot_review_train.as_matrix()
pivot_test = pivot_review_test.as_matrix()
pivot_user_train_ = pivot_user_train.as_matrix()
pivot_user_test_ = pivot_user_test.as_matrix()
pivot_business_train_ = pivot_business_train.as_matrix()
pivot_business_test_ = pivot_business_test.as_matrix()

# %%
# predict on train set: add the item-item & restaurant-restaurant residuals to the train set mean rating
pivot_pred_train = np.add(item_prediction, pivot_user_train_)
pivot_pred_train = np.add(pivot_pred_train, user_prediction)

# predict on trest set: add the item-item & restaurant-restaurant residuals to the test set mean rating
pivot_pred_test = np.add(item_prediction_test, pivot_user_test_)
pivot_pred_test = np.add(pivot_pred_test, user_prediction_test)

# %%
# calculate RMSE for test and train set
print("CF Train RMSE score is {}".format(cf_rmse(pivot_train, pivot_pred_train)))
print("CF Test RMSE score is {}".format(cf_rmse(pivot_test, pivot_pred_test)))
# Out:
# CF Train RMSE score is 0.08932886240815875
# CF Test RMSE score is 0.05339812124201512
